# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C:\\Users\\adity\\IMC_Prosperity\\first_strat_results.csv", sep=";", engine="python")

# %%
df.head()
# Out:
#    day  timestamp           product  bid_price_1  bid_volume_1  bid_price_2  \
# 0   -1          0  RAINFOREST_RESIN        10002             1       9996.0
# 1   -1          0              KELP         2028             1       2026.0
# 2   -1        100              KELP         2025            24          NaN
# 3   -1        100  RAINFOREST_RESIN         9996             2       9995.0
# 4   -1        200  RAINFOREST_RESIN         9995            20          NaN
#
#    bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  ask_volume_1  \
# 0           2.0       9995.0          29.0        10004             2
# 1           2.0       2025.0          29.0         2029            31
# 2           NaN          NaN           NaN         2028             2
# 3          22.0          NaN           NaN        10004             2
# 4           NaN          NaN           NaN        10005            20
#
#    ask_price_2  ask_volume_2  ask_price_3  ask_volume_3  mid_price  \
# ...

# %%
df.head(100)
# Out:
#     day  timestamp           product  bid_price_1  bid_volume_1  bid_price_2  \
# 0    -1          0  RAINFOREST_RESIN        10002             1       9996.0
# 1    -1          0              KELP         2028             1       2026.0
# 2    -1        100              KELP         2025            24          NaN
# 3    -1        100  RAINFOREST_RESIN         9996             2       9995.0
# 4    -1        200  RAINFOREST_RESIN         9995            20          NaN
# ..  ...        ...               ...          ...           ...          ...
# 95   -1       4700  RAINFOREST_RESIN         9996             2       9995.0
# 96   -1       4800              KELP         2023            24          NaN
# 97   -1       4800  RAINFOREST_RESIN         9998             6       9996.0
# 98   -1       4900  RAINFOREST_RESIN         9995            22          NaN
# 99   -1       4900              KELP         2023            22          NaN
#
# ...

# %%
df.columns
# Out:
# Index(['day', 'timestamp', 'product', 'bid_price_1', 'bid_volume_1',
#        'bid_price_2', 'bid_volume_2', 'bid_price_3', 'bid_volume_3',
#        'ask_price_1', 'ask_volume_1', 'ask_price_2', 'ask_volume_2',
#        'ask_price_3', 'ask_volume_3', 'mid_price', 'profit_and_loss'],
#       dtype='object')

# %%
df.fillna(0, inplace = True)

# %%
df.head()
# Out:
#    day  timestamp           product  bid_price_1  bid_volume_1  bid_price_2  \
# 0   -1          0  RAINFOREST_RESIN        10002             1       9996.0
# 1   -1          0              KELP         2028             1       2026.0
# 2   -1        100              KELP         2025            24          0.0
# 3   -1        100  RAINFOREST_RESIN         9996             2       9995.0
# 4   -1        200  RAINFOREST_RESIN         9995            20          0.0
#
#    bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  ask_volume_1  \
# 0           2.0       9995.0          29.0        10004             2
# 1           2.0       2025.0          29.0         2029            31
# 2           0.0          0.0           0.0         2028             2
# 3          22.0          0.0           0.0        10004             2
# 4           0.0          0.0           0.0        10005            20
#
#    ask_price_2  ask_volume_2  ask_price_3  ask_volume_3  mid_price  \
# ...

# %%
df_resin = df[df['product'] == "RAINFOREST_RESIN"]

# %%
df_resin.head()
# Out:
#    day  timestamp           product  bid_price_1  bid_volume_1  bid_price_2  \
# 0   -1          0  RAINFOREST_RESIN        10002             1       9996.0
# 3   -1        100  RAINFOREST_RESIN         9996             2       9995.0
# 4   -1        200  RAINFOREST_RESIN         9995            20          0.0
# 7   -1        300  RAINFOREST_RESIN         9996             2       9995.0
# 8   -1        400  RAINFOREST_RESIN         9996             2       9995.0
#
#    bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  ask_volume_1  \
# 0           2.0       9995.0          29.0        10004             2
# 3          22.0          0.0           0.0        10004             2
# 4           0.0          0.0           0.0        10005            20
# 7          29.0          0.0           0.0        10004             2
# 8          25.0          0.0           0.0        10004             2
#
#    ask_price_2  ask_volume_2  ask_price_3  ask_volume_3  mid_price  \
# ...

# %%
df_kelp = df[df['product'] == "KELP"]

# %%
df_kelp.head()
# Out:
#    day  timestamp product  bid_price_1  bid_volume_1  bid_price_2  \
# 1   -1          0    KELP         2028             1       2026.0
# 2   -1        100    KELP         2025            24          0.0
# 5   -1        200    KELP         2025            22          0.0
# 6   -1        300    KELP         2025            31          0.0
# 9   -1        400    KELP         2025            27          0.0
#
#    bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  ask_volume_1  \
# 1           2.0       2025.0          29.0         2029            31
# 2           0.0          0.0           0.0         2028             2
# 5           0.0          0.0           0.0         2028            20
# 6           0.0          0.0           0.0         2028             2
# 9           0.0          0.0           0.0         2028            27
#
#    ask_price_2  ask_volume_2  ask_price_3  ask_volume_3  mid_price  \
# 1          0.0           0.0          0.0           0.0     2028.5
# ...

# %%
df_resin.to_csv("resin_order_book.csv", index = False)

# %%
df_kelp.to_csv("kelp_order_book.csv", index = False)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.lineplot(x = df_resin['timestamp'], y = df_resin['mid_price'])
plt.title("Variation of Resin Prices")
plt.xlabel("Time")
plt.ylabel("Resin Price")
plt.show()

# %%
sns.lineplot(x = df_kelp['timestamp'], y = df_kelp['mid_price'])
plt.title("Variation of Kelp Prices")
plt.xlabel("Time")
plt.ylabel("Kelp Price")
plt.show()
